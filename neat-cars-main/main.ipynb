# %%
# ------------------ IMPORTS ------------------


from render.engine import Engine


# ------------------ GLOBAL VARIABLES ------------------


NEAT_CONFIG_PATH = "ai/config.txt"
RAY_CAST = True
MAX_SIMULATIONS = 1000


# ------------------ MAIN FUNCTION ------------------


def main() -> None:
    window = Engine(NEAT_CONFIG_PATH, RAY_CAST, MAX_SIMULATIONS)
    window.run()


# ------------------ MAIN CALL ------------------


if __name__ == "__main__":
    main()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.08557 stdev: 0.14687
# Best fitness: 0.81940 - size: (4, 20) - species 1 - id 29
# Average adjusted fitness: 0.076
# Mean genetic distance 1.192, standard deviation 0.232
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    50      0.8    0.076     0
# Total extinctions: 0
# Generation time: 1.375 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.15267 stdev: 0.17061
# Best fitness: 0.81940 - size: (4, 20) - species 1 - id 29
# Average adjusted fitness: 0.143
# Mean genetic distance 1.229, standard deviation 0.233
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    50      0.8    0.143     1
# Total extinctions: 0
# Generation time: 1.378 sec (1.377 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 0.21625 stdev: 0.30099
# Best fitness: 1.69380 - size: (4, 18) - species 1 - id 102
# Average adjusted fitness: 0.122
# Mean genetic distance 1.283, standard deviation 0.209
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    50      1.7    0.122     0
# Total extinctions: 0
# Generation time: 2.056 sec (1.603 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 0.34386 stdev: 0.71226
# Best fitness: 4.56580 - size: (4, 20) - species 1 - id 159
# Average adjusted fitness: 0.073
# Mean genetic distance 1.307, standard deviation 0.254
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    50      4.6    0.073     0
# Total extinctions: 0
# Generation time: 3.359 sec (2.042 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 0.56785 stdev: 0.79463
# Best fitness: 4.56580 - size: (4, 20) - species 1 - id 159
# Average adjusted fitness: 0.122
# Mean genetic distance 1.374, standard deviation 0.282
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    50      4.6    0.122     1
# Total extinctions: 0
# Generation time: 3.367 sec (2.307 average)
#
#  ****** Running generation 5 ******
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [1], in <cell line: 26>()
#      23 # ------------------ MAIN CALL ------------------
#      26 if __name__ == "__main__":
# ---> 27     main()
#
# Input In [1], in main()
#      18 def main() -> None:
#      19     window = Engine(NEAT_CONFIG_PATH, RAY_CAST, MAX_SIMULATIONS)
# ---> 20     window.run()
#
# File ~\neat-cars-main\render\engine.py:128, in Engine.run(self)
#     126 # AI
#     127 if self.ai_can_start:
# --> 128     self.start_ai()
#     130 # Update
#     131 self.update()
#
# File ~\neat-cars-main\render\engine.py:155, in Engine.start_ai(self)
#     152     population.add_reporter(neat.StatisticsReporter())
#     154 # Run simulation for MAX_SIMULATION generations
# --> 155 population.run(self.run_simulation, self.MAX_SIMULATIONS)
#
# File ~\anaconda3\lib\site-packages\neat\population.py:89, in Population.run(self, fitness_function, n)
#      86 self.reporters.start_generation(self.generation)
#      88 # Evaluate all genomes using the user-provided function.
# ---> 89 fitness_function(list(iteritems(self.population)), self.config)
#      91 # Gather and report statistics.
#      92 best = None
#
# File ~\neat-cars-main\render\engine.py:192, in Engine.run_simulation(self, genomes, config)
#     189     break
#     191 # Draw the track and cars which are still alive
# --> 192 self.screen.blit(self.track, (0, 0))
#     193 for car in car_ai.cars:
#     194     car.draw(self.screen)
#
# error: display Surface quit
